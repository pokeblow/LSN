# %% [markdown]
# # Stage 1: Pre Training

# %%
import runpy
runpy.run_module("train_pre", run_name="__main__")

# %% [markdown]
# # Stage 2: Main Training

# %%
import runpy
runpy.run_module("train_pre", run_name="__main__")
